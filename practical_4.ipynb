# %% [markdown]
# <a href="https://colab.research.google.com/github/kundanpandit/DATA_MINING_PRACTICALS/blob/main/practical_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install efficient-apriori
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
from efficient_apriori import apriori
import pandas as pd

# %%
transactions = [
['Milk', "Diaper", "Tea"],
['Milk','Diaper','Tea','Bread','Butter'],
['Milk','Diaper','Tea'],
['Milk','Diaper','Bread','Butter'],
['Milk','Diaper','Bread','Butter','Tea']
]

# %%
transactions
# Out:
# [['Milk', 'Diaper', 'Tea'],
#  ['Milk', 'Diaper', 'Tea', 'Bread', 'Butter'],
#  ['Milk', 'Diaper', 'Tea'],
#  ['Milk', 'Diaper', 'Bread', 'Butter'],
#  ['Milk', 'Diaper', 'Bread', 'Butter', 'Tea']]

# %%
itemsets, rules = apriori(transactions, min_support=0.5, min_confidence=0.75)

# %%
itemsets
# Out:
# {1: {('Milk',): 5, ('Diaper',): 5, ('Tea',): 4, ('Bread',): 3, ('Butter',): 3},
#  2: {('Bread', 'Butter'): 3,
#   ('Bread', 'Diaper'): 3,
#   ('Bread', 'Milk'): 3,
#   ('Butter', 'Diaper'): 3,
#   ('Butter', 'Milk'): 3,
#   ('Diaper', 'Milk'): 5,
#   ('Diaper', 'Tea'): 4,
#   ('Milk', 'Tea'): 4},
#  3: {('Bread', 'Butter', 'Diaper'): 3,
#   ('Bread', 'Butter', 'Milk'): 3,
#   ('Bread', 'Diaper', 'Milk'): 3,
#   ('Butter', 'Diaper', 'Milk'): 3,
#   ('Diaper', 'Milk', 'Tea'): 4},
#  4: {('Bread', 'Butter', 'Diaper', 'Milk'): 3}}

# %%
rules
# Out:
# [{Butter} -> {Bread},
#  {Bread} -> {Butter},
#  {Bread} -> {Diaper},
#  {Bread} -> {Milk},
#  {Butter} -> {Diaper},
#  {Butter} -> {Milk},
#  {Milk} -> {Diaper},
#  {Diaper} -> {Milk},
#  {Tea} -> {Diaper},
#  {Diaper} -> {Tea},
#  {Tea} -> {Milk},
#  {Milk} -> {Tea},
#  {Butter, Diaper} -> {Bread},
#  {Bread, Diaper} -> {Butter},
#  {Bread, Butter} -> {Diaper},
#  {Butter} -> {Bread, Diaper},
#  {Bread} -> {Butter, Diaper},
#  {Butter, Milk} -> {Bread},
#  {Bread, Milk} -> {Butter},
#  {Bread, Butter} -> {Milk},
#  {Butter} -> {Bread, Milk},
#  {Bread} -> {Butter, Milk},
#  {Bread, Milk} -> {Diaper},
#  {Bread, Diaper} -> {Milk},
#  {Bread} -> {Diaper, Milk},
#  {Butter, Milk} -> {Diaper},
#  {Butter, Diaper} -> {Milk},
#  {Butter} -> {Diaper, Milk},
#  {Milk, Tea} -> {Diaper},
#  {Diaper, Tea} -> {Milk},
#  {Diaper, Milk} -> {Tea},
#  {Tea} -> {Diaper, Milk},
#  {Milk} -> {Diaper, Tea},
#  {Diaper} -> {Milk, Tea},
#  {Butter, Diaper, Milk} -> {Bread},
# ...

# %%
itemsets, rules = apriori(transactions, min_support=1, min_confidence=1)

# %%
itemsets
# Out:
# {1: {('Milk',): 5, ('Diaper',): 5}, 2: {('Diaper', 'Milk'): 5}}

# %%
rules
# Out:
# [{Milk} -> {Diaper}, {Diaper} -> {Milk}]

# %%
df=pd.read_csv("groceries.csv")

# %%
df.head(1)
# Out:
#    Item(s)        Item 1               Item 2     Item 3       Item 4 Item 5  \
# 0        4  citrus fruit  semi-finished bread  margarine  ready soups    NaN
#
#   Item 6 Item 7 Item 8 Item 9  ... Item 23 Item 24 Item 25 Item 26 Item 27  \
# 0    NaN    NaN    NaN    NaN  ...     NaN     NaN     NaN     NaN     NaN
#
#   Item 28 Item 29 Item 30 Item 31 Item 32
# 0     NaN     NaN     NaN     NaN     NaN
#
# [1 rows x 33 columns]

# %%
df.shape
# Out:
# (9835, 33)

# %%
df.isnull().sum()
# Out:
# Item(s)       0
# Item 1        0
# Item 2     2159
# Item 3     3802
# Item 4     5101
# Item 5     6106
# Item 6     6961
# Item 7     7606
# Item 8     8151
# Item 9     8589
# Item 10    8939
# Item 11    9185
# Item 12    9367
# Item 13    9484
# Item 14    9562
# Item 15    9639
# Item 16    9694
# Item 17    9740
# Item 18    9769
# Item 19    9783
# Item 20    9797
# Item 21    9806
# Item 22    9817
# Item 23    9821
# Item 24    9827
# Item 25    9828
# Item 26    9828
# Item 27    9829
# Item 28    9830
# Item 29    9831
# Item 30    9834
# Item 31    9834
# Item 32    9834
# dtype: int64

# %%
df.dropna(thresh=5, inplace=True)

# %%
df.head()
# Out:
#    Item(s)            Item 1               Item 2          Item 3  \
# 0        4      citrus fruit  semi-finished bread       margarine
# 3        4         pip fruit               yogurt    cream cheese
# 4        4  other vegetables           whole milk  condensed milk
# 5        5        whole milk               butter          yogurt
# 7        5  other vegetables             UHT-milk      rolls/buns
#
#                      Item 4              Item 5 Item 6 Item 7 Item 8 Item 9  \
# 0               ready soups                 NaN    NaN    NaN    NaN    NaN
# 3              meat spreads                 NaN    NaN    NaN    NaN    NaN
# 4  long life bakery product                 NaN    NaN    NaN    NaN    NaN
# 5                      rice    abrasive cleaner    NaN    NaN    NaN    NaN
# 7              bottled beer  liquor (appetizer)    NaN    NaN    NaN    NaN
#
#    ... Item 23 Item 24 Item 25 Item 26 Item 27 Item 28 Item 29 Item 30  \
# ...

# %%
df.shape
# Out:
# (4734, 33)

# %%
df.isnull().sum()
# Out:
# Item(s)       0
# Item 1        0
# Item 2        0
# Item 3        0
# Item 4        0
# Item 5     1005
# Item 6     1860
# Item 7     2505
# Item 8     3050
# Item 9     3488
# Item 10    3838
# Item 11    4084
# Item 12    4266
# Item 13    4383
# Item 14    4461
# Item 15    4538
# Item 16    4593
# Item 17    4639
# Item 18    4668
# Item 19    4682
# Item 20    4696
# Item 21    4705
# Item 22    4716
# Item 23    4720
# Item 24    4726
# Item 25    4727
# Item 26    4727
# Item 27    4728
# Item 28    4729
# Item 29    4730
# Item 30    4733
# Item 31    4733
# Item 32    4733
# dtype: int64

# %%
4734 - 1005
# Out:
# 3729

# %%
 df.dropna(thresh=3729, inplace=True, axis=1)

# %%
df.head()
# Out:
#    Item(s)            Item 1               Item 2          Item 3  \
# 0        4      citrus fruit  semi-finished bread       margarine
# 3        4         pip fruit               yogurt    cream cheese
# 4        4  other vegetables           whole milk  condensed milk
# 5        5        whole milk               butter          yogurt
# 7        5  other vegetables             UHT-milk      rolls/buns
#
#                      Item 4              Item 5
# 0               ready soups                 NaN
# 3              meat spreads                 NaN
# 4  long life bakery product                 NaN
# 5                      rice    abrasive cleaner
# 7              bottled beer  liquor (appetizer)

# %%
df.isnull().sum()
# Out:
# Item(s)       0
# Item 1        0
# Item 2        0
# Item 3        0
# Item 4        0
# Item 5     1005
# dtype: int64

# %%
df = df.fillna(method="ffill", limit=3)

# %%
df.isnull().sum()
# Out:
# Item(s)     0
# Item 1      0
# Item 2      0
# Item 3      0
# Item 4      0
# Item 5     14
# dtype: int64

# %%
df = df.fillna(method="bfill", limit=3)

# %%
df.isnull().sum()
# Out:
# Item(s)    0
# Item 1     0
# Item 2     0
# Item 3     0
# Item 4     0
# Item 5     0
# dtype: int64

# %%
df.drop(["Item(s)"], axis=1, inplace=True)

# %%
df.head(3)
# Out:
#              Item 1               Item 2          Item 3  \
# 0      citrus fruit  semi-finished bread       margarine
# 3         pip fruit               yogurt    cream cheese
# 4  other vegetables           whole milk  condensed milk
#
#                      Item 4            Item 5
# 0               ready soups  abrasive cleaner
# 3              meat spreads  abrasive cleaner
# 4  long life bakery product  abrasive cleaner

# %%
len(df["Item 1"].unique())
# Out:
# 85

# %%
df["Item 1"].value_counts().head(20)
# Out:
# sausage             627
# frankfurter         464
# citrus fruit        347
# tropical fruit      343
# whole milk          298
# pork                287
# other vegetables    258
# chicken             236
# beef                227
# root vegetables     190
# pip fruit           170
# ham                 160
# meat                134
# hamburger meat      125
# yogurt               80
# berries              79
# rolls/buns           44
# turkey               43
# onions               42
# grapes               41
# Name: Item 1, dtype: int64

# %%
df["Item 1"].value_counts().head(20).plot(kind="bar")
# Out:
# <Axes: >

# %%
print(len(df["Item 2"].unique()))
print(df["Item 2"].value_counts().head(20))
# Out:
# 114
# whole milk          517
# other vegetables    445
# root vegetables     352
# tropical fruit      331
# citrus fruit        225
# pip fruit           213
# yogurt              172
# beef                143
# rolls/buns          138
# pork                130
# hamburger meat      107
# sausage              96
# chicken              87
# butter               86
# berries              82
# onions               77
# curd                 77
# meat                 71
# dessert              69
# soda                 66
# Name: Item 2, dtype: int64

# %%
df["Item 2"].value_counts().head(20).plot(kind="bar")
# Out:
# <Axes: >

# %%
print(len(df["Item 3"].unique()))
print(df["Item 3"].value_counts().head(20))
# Out:
# 143
# whole milk            485
# other vegetables      397
# yogurt                263
# rolls/buns            244
# root vegetables       205
# tropical fruit        143
# pip fruit             143
# soda                  139
# pastry                111
# butter                107
# whipped/sour cream    104
# curd                   95
# bottled water          91
# domestic eggs          85
# citrus fruit           84
# frozen vegetables      75
# onions                 73
# brown bread            71
# UHT-milk               65
# cream cheese           63
# Name: Item 3, dtype: int64

# %%
df["Item 3"].value_counts().head(20).plot(kind="bar")
# Out:
# <Axes: >

# %%
print(len(df["Item 4"].unique()))
print(df["Item 4"].value_counts().head(20))
# Out:
# 153
# whole milk               315
# other vegetables         254
# rolls/buns               238
# soda                     211
# yogurt                   202
# bottled water            138
# pastry                   127
# whipped/sour cream       114
# shopping bags            112
# root vegetables          108
# domestic eggs             97
# brown bread               94
# butter                    90
# curd                      87
# margarine                 83
# fruit/vegetable juice     82
# newspapers                81
# bottled beer              78
# canned beer               74
# pip fruit                 72
# Name: Item 4, dtype: int64

# %%
df["Item 4"].value_counts().head(20).plot(kind="bar")
# Out:
# <Axes: >

# %%
df1=df.values.tolist()
df1
# Out:
# [['citrus fruit',
#   'semi-finished bread',
#   'margarine',
#   'ready soups',
#   'abrasive cleaner'],
#  ['pip fruit', 'yogurt', 'cream cheese', 'meat spreads', 'abrasive cleaner'],
#  ['other vegetables',
#   'whole milk',
#   'condensed milk',
#   'long life bakery product',
#   'abrasive cleaner'],
#  ['whole milk', 'butter', 'yogurt', 'rice', 'abrasive cleaner'],
#  ['other vegetables',
#   'UHT-milk',
#   'rolls/buns',
#   'bottled beer',
#   'liquor (appetizer)'],
#  ['tropical fruit',
#   'other vegetables',
#   'white bread',
#   'bottled water',
#   'chocolate'],
#  ['citrus fruit', 'tropical fruit', 'whole milk', 'butter', 'curd'],
#  ['butter', 'sugar', 'fruit/vegetable juice', 'newspapers', 'curd'],
#  ['tropical fruit',
#   'cream cheese',
#   'processed cheese',
#   'detergent',
#   'newspapers'],
#  ['tropical fruit',
#   'root vegetables',
#   'other vegetables',
#   'frozen dessert',
#   'rolls/buns'],
# ...

# %%
itemsets, rules = apriori(df1, min_support=0.02, min_confidence=0.05)
itemsets
# Out:
# {1: {('citrus fruit',): 691,
#   ('margarine',): 275,
#   ('pip fruit',): 609,
#   ('yogurt',): 913,
#   ('cream cheese',): 232,
#   ('other vegetables',): 1497,
#   ('whole milk',): 1792,
#   ('long life bakery product',): 117,
#   ('butter',): 406,
#   ('UHT-milk',): 236,
#   ('rolls/buns',): 886,
#   ('bottled beer',): 256,
#   ('tropical fruit',): 866,
#   ('white bread',): 197,
#   ('bottled water',): 459,
#   ('chocolate',): 131,
#   ('curd',): 385,
#   ('sugar',): 132,
#   ('fruit/vegetable juice',): 230,
#   ('newspapers',): 192,
#   ('processed cheese',): 98,
#   ('root vegetables',): 915,
#   ('sausage',): 723,
#   ('soda',): 644,
#   ('brown bread',): 324,
#   ('canned beer',): 198,
#   ('beverages',): 154,
#   ('hamburger meat',): 279,
#   ('pork',): 464,
#   ('berries',): 283,
#   ('whipped/sour cream',): 423,
#   ('dessert',): 262,
#   ('domestic eggs',): 355,
#   ('butter milk',): 192,
#   ('ham',): 227,
#   ('grapes',): 183,
#   ('pastry',): 410,
#   ('oil',): 106,
# ...

# %%
rules
# Out:
# [{other vegetables} -> {beef},
#  {beef} -> {other vegetables},
#  {root vegetables} -> {beef},
#  {beef} -> {root vegetables},
#  {whole milk} -> {beef},
#  {beef} -> {whole milk},
#  {soda} -> {bottled water},
#  {bottled water} -> {soda},
#  {whole milk} -> {bottled water},
#  {bottled water} -> {whole milk},
#  {whole milk} -> {brown bread},
#  {brown bread} -> {whole milk},
#  {other vegetables} -> {butter},
#  {butter} -> {other vegetables},
#  {whole milk} -> {butter},
#  {butter} -> {whole milk},
#  {other vegetables} -> {chicken},
#  {chicken} -> {other vegetables},
#  {whole milk} -> {chicken},
#  {chicken} -> {whole milk},
#  {other vegetables} -> {citrus fruit},
#  {citrus fruit} -> {other vegetables},
#  {pip fruit} -> {citrus fruit},
#  {citrus fruit} -> {pip fruit},
#  {root vegetables} -> {citrus fruit},
#  {citrus fruit} -> {root vegetables},
#  {sausage} -> {citrus fruit},
#  {citrus fruit} -> {sausage},
#  {tropical fruit} -> {citrus fruit},
# ...

# %%
new_df = pd.read_csv('bake.csv')

# %%
new_df.columns = ["Receipt", "food", "quantity"]

# %%
new_df.head()
# Out:
#    Receipt  food  quantity
# 0        1     4        15
# 1        1     2        49
# 2        1     5        44
# 3        2     1         1
# 4        2     2        19

# %%
new_df.isna().sum()
# Out:
# Receipt     0
# food        0
# quantity    0
# dtype: int64

# %%
new_df.describe()
# Out:
#            Receipt         food     quantity
# count  3537.000000  3537.000000  3537.000000
# mean    498.145321     2.986146    24.223353
# std     289.283458     1.403204    14.722389
# min       1.000000     1.000000     0.000000
# 25%     244.000000     2.000000    12.000000
# 50%     496.000000     3.000000    24.000000
# 75%     754.000000     4.000000    37.000000
# max    1000.000000     5.000000    49.000000

# %%
new_df.head()
# Out:
#    Receipt  food  quantity
# 0        1     4        15
# 1        1     2        49
# 2        1     5        44
# 3        2     1         1
# 4        2     2        19

# %%
new_df["food"] = new_df["food"].map({1:"milk",2:"sugar",3:"chocolate",4:"apples",5:"curd"})

# %%
new_df.head()
# Out:
#    Receipt    food  quantity
# 0        1  apples        15
# 1        1   sugar        49
# 2        1    curd        44
# 3        2    milk         1
# 4        2   sugar        19

# %%
li = []
for i in new_df["Receipt"].unique():
 
 li.append([])

# %%
for i in range(new_df.shape[0]):
 
 li[new_df["Receipt"][i] - 1].append(new_df["food"][i])

# %%
li
# Out:
# [['apples', 'sugar', 'curd'],
#  ['milk', 'sugar'],
#  ['milk', 'milk'],
#  ['milk', 'milk', 'curd', 'curd', 'milk', 'milk'],
#  ['apples', 'apples', 'sugar', 'curd', 'curd'],
#  ['sugar', 'apples', 'chocolate'],
#  ['apples', 'chocolate', 'sugar', 'milk', 'milk', 'milk'],
#  ['curd', 'milk', 'chocolate'],
#  ['chocolate', 'milk'],
#  ['curd', 'sugar', 'milk'],
#  ['apples', 'curd', 'milk', 'sugar', 'curd'],
#  ['milk', 'apples', 'chocolate'],
#  ['apples'],
#  ['sugar', 'chocolate', 'sugar'],
#  ['curd', 'chocolate', 'apples'],
#  ['sugar', 'sugar', 'milk'],
#  ['sugar', 'milk', 'sugar', 'curd', 'chocolate', 'chocolate'],
#  ['sugar', 'curd', 'chocolate'],
#  ['sugar', 'apples', 'sugar', 'curd'],
#  ['apples', 'apples', 'apples', 'chocolate'],
#  ['apples', 'chocolate', 'milk', 'curd'],
#  ['sugar', 'milk', 'chocolate'],
#  ['chocolate', 'curd'],
#  ['apples', 'apples', 'curd'],
#  ['chocolate', 'chocolate', 'milk'],
#  ['curd', 'apples', 'sugar'],
# ...

# %%
itemsets, rules = apriori(li, min_support=0.02, min_confidence=0.05)

# %%
itemsets
# Out:
# {1: {('apples',): 540,
#   ('sugar',): 498,
#   ('curd',): 493,
#   ('milk',): 542,
#   ('chocolate',): 506},
#  2: {('apples', 'chocolate'): 250,
#   ('apples', 'curd'): 264,
#   ('apples', 'milk'): 271,
#   ('apples', 'sugar'): 258,
#   ('chocolate', 'curd'): 231,
#   ('chocolate', 'milk'): 251,
#   ('chocolate', 'sugar'): 239,
#   ('curd', 'milk'): 240,
#   ('curd', 'sugar'): 230,
#   ('milk', 'sugar'): 254},
#  3: {('apples', 'chocolate', 'curd'): 112,
#   ('apples', 'chocolate', 'milk'): 120,
#   ('apples', 'chocolate', 'sugar'): 116,
#   ('apples', 'curd', 'milk'): 120,
#   ('apples', 'curd', 'sugar'): 122,
#   ('apples', 'milk', 'sugar'): 124,
#   ('chocolate', 'curd', 'milk'): 115,
#   ('chocolate', 'curd', 'sugar'): 115,
#   ('chocolate', 'milk', 'sugar'): 109,
#   ('curd', 'milk', 'sugar'): 98},
#  4: {('apples', 'chocolate', 'curd', 'milk'): 56,
#   ('apples', 'chocolate', 'curd', 'sugar'): 57,
#   ('apples', 'chocolate', 'milk', 'sugar'): 53,
# ...

# %%
rules
# Out:
# [{chocolate} -> {apples},
#  {apples} -> {chocolate},
#  {curd} -> {apples},
#  {apples} -> {curd},
#  {milk} -> {apples},
#  {apples} -> {milk},
#  {sugar} -> {apples},
#  {apples} -> {sugar},
#  {curd} -> {chocolate},
#  {chocolate} -> {curd},
#  {milk} -> {chocolate},
#  {chocolate} -> {milk},
#  {sugar} -> {chocolate},
#  {chocolate} -> {sugar},
#  {milk} -> {curd},
#  {curd} -> {milk},
#  {sugar} -> {curd},
#  {curd} -> {sugar},
#  {sugar} -> {milk},
#  {milk} -> {sugar},
#  {chocolate, curd} -> {apples},
#  {apples, curd} -> {chocolate},
#  {apples, chocolate} -> {curd},
#  {curd} -> {apples, chocolate},
#  {chocolate} -> {apples, curd},
#  {apples} -> {chocolate, curd},
#  {chocolate, milk} -> {apples},
#  {apples, milk} -> {chocolate},
#  {apples, chocolate} -> {milk},
#  {milk} -> {apples, chocolate},
#  {chocolate} -> {apples, milk},
#  {apples} -> {chocolate, milk},
#  {chocolate, sugar} -> {apples},
#  {apples, sugar} -> {chocolate},
#  {apples, chocolate} -> {sugar},
# ...

# %%
print(len(new_df["food"].unique()))
print(new_df["food"].value_counts())
# Out:
# 5
# apples       768
# milk         721
# chocolate    705
# sugar        687
# curd         656
# Name: food, dtype: int64

# %%
new_df["food"].value_counts().plot(kind="bar")
# Out:
# <Axes: >
